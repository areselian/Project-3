# %%
#Import Dependencies

import pandas as pd
import numpy as np
from datetime import datetime
import sqlalchemy

# %%
#Read in csvs

players = pd.read_csv('players.csv')
salaries = pd.read_csv('salaries.csv')
coords = pd.read_csv('Coords.csv')

# %%
#Merge Players and Salaries on (_id and player_id)

players = pd.merge(players, salaries, left_on = '_id', right_on = 'player_id')

# %%
#Choose an appropriate format for useful fields

players['draft_year'] = players['draft_year'].astype(float)
players['position'] = players['position'].astype(str)

# %%
#limit data to 2010 and beyond

players = players[players.draft_year >= 2000]

# %%
# Select columns for dataframe

players_cols = ['player_id','birthDate','draft_year','name','position',
                'college','salary','season_end','season_start','team']

# %%
# Applied to dataframe

players = players[players_cols]

# %%
# Drop Nulls

players = players.dropna()

# %%
players.dtypes
players['player_id'] = players['player_id'].astype(str)

# %%
# Prep coords.csv for merging

coords = coords.rename(columns={"name":"college"})

# %%
# Merge players and coords

merged = pd.merge(players, coords, how='right', on='college')

# %%
merged
# Out:
#        player_id        birthDate  draft_year        name  \
# 0        acyqu01  October 6, 1990      2012.0  Quincy Acy
# 1        acyqu01  October 6, 1990      2012.0  Quincy Acy
# 2        acyqu01  October 6, 1990      2012.0  Quincy Acy
# 3        acyqu01  October 6, 1990      2012.0  Quincy Acy
# 4        acyqu01  October 6, 1990      2012.0  Quincy Acy
# ...          ...              ...         ...         ...
# 89204  youngjo01    June 27, 1992      2015.0   Joe Young
# 89205  youngjo01    June 27, 1992      2015.0   Joe Young
# 89206  youngjo01    June 27, 1992      2015.0   Joe Young
# 89207  youngjo01    June 27, 1992      2015.0   Joe Young
# 89208  youngjo01    June 27, 1992      2015.0   Joe Young
#
#                               position  \
# 0      Power Forward and Small Forward
# 1      Power Forward and Small Forward
# 2      Power Forward and Small Forward
# 3      Power Forward and Small Forward
# 4      Power Forward and Small Forward
# ...                                ...
# 89204                      Point Guard
# 89205                      Point Guard
# 89206                      Point Guard
# 89207                      Point Guard
# 89208                      Point Guard
#
#                                            college   salary  season_end  \
# 0                                Baylor University   665000        2013
# 1                                Baylor University   788872        2014
# 2                                Baylor University   915243        2015
# 3                                Baylor University   981348        2016
# 4                                Baylor University  1914544        2017
# ...                                            ...      ...         ...
# 89204  University of Houston, University of Oregon  1052342        2017
# 89205  University of Houston, University of Oregon  1471382        2018
# 89206  University of Houston, University of Oregon  1000000        2016
# 89207  University of Houston, University of Oregon  1052342        2017
# 89208  University of Houston, University of Oregon  1471382        2018
#
#        season_start              team        lat        long
# 0              2012   Toronto Raptors  31.546913  -97.121100
# 1              2013   Toronto Raptors  31.546913  -97.121100
# 2              2014   New York Knicks  31.546913  -97.121100
# 3              2015  Sacramento Kings  31.546913  -97.121100
# 4              2016     Brooklyn Nets  31.546913  -97.121100
# ...             ...               ...        ...         ...
# 89204          2016    Indiana Pacers  44.044830 -123.072605
# 89205          2017    Indiana Pacers  44.044830 -123.072605
# 89206          2015    Indiana Pacers  44.044830 -123.072605
# 89207          2016    Indiana Pacers  44.044830 -123.072605
# 89208          2017    Indiana Pacers  44.044830 -123.072605
#
# [89209 rows x 12 columns]

# %%
#Find max salary by id and save to idx

idx = merged.groupby(['player_id'])['salary'].transform(max) == merged['salary']

# %%
# Applied idx to dataframe

merged = merged[idx]

# %%
merged
# Out:
#        player_id           birthDate  draft_year             name  \
# 4        acyqu01     October 6, 1990      2012.0       Quincy Acy
# 8      jackspi01     August 29, 1991      2013.0   Pierre Jackson
# 10     jeffeco01   December 26, 1990      2014.0   Cory Jefferson
# 15     jonespe01  September 24, 1991      2012.0      Perry Jones
# 17     millequ01   November 18, 1992      2012.0    Quincy Miller
# ...          ...                 ...         ...              ...
# 89184  williel01       June 20, 1989      2010.0  Elliot Williams
# 89193  williel01       June 20, 1989      2010.0  Elliot Williams
# 89202  youngjo01       June 27, 1992      2015.0        Joe Young
# 89205  youngjo01       June 27, 1992      2015.0        Joe Young
# 89208  youngjo01       June 27, 1992      2015.0        Joe Young
#
#                               position  \
# 4      Power Forward and Small Forward
# 8                          Point Guard
# 10                       Power Forward
# 15     Small Forward and Power Forward
# 17                       Power Forward
# ...                                ...
# 89184   Point Guard and Shooting Guard
# 89193   Point Guard and Shooting Guard
# 89202                      Point Guard
# 89205                      Point Guard
# 89208                      Point Guard
#
#                                            college   salary  season_end  \
# 4                                Baylor University  1914544        2017
# 8                                Baylor University   750000        2016
# 10                               Baylor University   507336        2015
# 15                               Baylor University  2038206        2016
# 17                               Baylor University   788872        2014
# ...                                            ...      ...         ...
# 89184       Duke University, University of Memphis  1442880        2013
# 89193       Duke University, University of Memphis  1442880        2013
# 89202  University of Houston, University of Oregon  1471382        2018
# 89205  University of Houston, University of Oregon  1471382        2018
# 89208  University of Houston, University of Oregon  1471382        2018
#
#        season_start                    team        lat        long
# 4              2016           Brooklyn Nets  31.546913  -97.121100
# 8              2015      Philadelphia 76ers  31.546913  -97.121100
# 10             2014           Brooklyn Nets  31.546913  -97.121100
# 15             2015          Boston Celtics  31.546913  -97.121100
# 17             2013          Denver Nuggets  31.546913  -97.121100
# ...             ...                     ...        ...         ...
# 89184          2012  Portland Trail Blazers  35.118750  -89.937493
# 89193          2012  Portland Trail Blazers  35.118750  -89.937493
# 89202          2017          Indiana Pacers  44.044830 -123.072605
# 89205          2017          Indiana Pacers  44.044830 -123.072605
# 89208          2017          Indiana Pacers  44.044830 -123.072605
#
# [16536 rows x 12 columns]

# %%
new_position= []
for position in merged.position:
    position = position.split(" ")
    if len(position) > 1:
        position_clear = position[0] + " " + position[1]
    else:
        position_clear = position[0]
    new_position.append(position_clear)

# %%
unique_college= []
for college1 in merged.college:
    college1 = college1.split(",")
    if len(college1) > 1:
        college_new = college1[1]
    else:
        college_new = college1[0]
    
    unique_college.append(college_new)

# %%
    print((unique_college))
# Out:
# ['Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'Baylor University', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona', 'University of Arizona',  ...

# %%
merged['college'] = unique_college
merged_duplicates = merged[merged.duplicated()]
print("Duplicate Rows except first occurrence based on all columns are :")
print(merged_duplicates)
1
2
3
4
5
# Select duplicate rows except first occurrence based on all columns
merged_duplicates = merged[merged.duplicated()]
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#        player_id           birthDate  draft_year             name  \
# 28       acyqu01     October 6, 1990      2012.0       Quincy Acy
# 32     jackspi01     August 29, 1991      2013.0   Pierre Jackson
# 34     jeffeco01   December 26, 1990      2014.0   Cory Jefferson
# 39     jonespe01  September 24, 1991      2012.0      Perry Jones
# 41     millequ01   November 18, 1992      2012.0    Quincy Miller
# ...          ...                 ...         ...              ...
# 89175  williel01       June 20, 1989      2010.0  Elliot Williams
# 89184  williel01       June 20, 1989      2010.0  Elliot Williams
# 89193  williel01       June 20, 1989      2010.0  Elliot Williams
# 89205  youngjo01       June 27, 1992      2015.0        Joe Young
# 89208  youngjo01       June 27, 1992      2015.0        Joe Young
#
#                               position                 college   salary  \
# 28     Power Forward and Small Forward       Baylor University  1914544
# 32                         Point Guard       Baylor University   750000
# 34                       Power Forward       Baylor University   507336
# 39     Small Forward and Power Forward       Baylor University  2038206
# 41                       Power Forward       Baylor University   788872
# ...                                ...                     ...      ...
# 89175   Point Guard and Shooting Guard   University of Memphis  1442880
# 89184   Point Guard and Shooting Guard   University of Memphis  1442880
# 89193   Point Guard and Shooting Guard   University of Memphis  1442880
# 89205                      Point Guard    University of Oregon  1471382
# 89208                      Point Guard    University of Oregon  1471382
#
#        season_end  season_start                    team        lat        long
# 28           2017          2016           Brooklyn Nets  31.546913  -97.121100
# 32           2016          2015      Philadelphia 76ers  31.546913  -97.121100
# 34           2015          2014           Brooklyn Nets  31.546913  -97.121100
# 39           2016          2015          Boston Celtics  31.546913  -97.121100
# 41           2014          2013          Denver Nuggets  31.546913  -97.121100
# ...           ...           ...                     ...        ...         ...
# 89175        2013          2012  Portland Trail Blazers  35.118750  -89.937493
# 89184        2013          2012  Portland Trail Blazers  35.118750  -89.937493
# 89193        2013          2012  Portland Trail Blazers  35.118750  -89.937493
# 89205        2018          2017          Indiana Pacers  44.044830 -123.072605
# 89208        2018          2017          Indiana Pacers  44.044830 -123.072605
#
# [15853 rows x 12 columns]
# C:\Users\vitor\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
merged['position'] = new_position
merged_duplicates = merged[merged.duplicated()]
print("Duplicate Rows except first occurrence based on all columns are :")
print(merged_duplicates)
1
2
3
4
5
# Select duplicate rows except first occurrence based on all columns
merged_duplicates = merged[merged.duplicated()]
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#        player_id           birthDate  draft_year             name  \
# 28       acyqu01     October 6, 1990      2012.0       Quincy Acy
# 32     jackspi01     August 29, 1991      2013.0   Pierre Jackson
# 34     jeffeco01   December 26, 1990      2014.0   Cory Jefferson
# 39     jonespe01  September 24, 1991      2012.0      Perry Jones
# 41     millequ01   November 18, 1992      2012.0    Quincy Miller
# ...          ...                 ...         ...              ...
# 89175  williel01       June 20, 1989      2010.0  Elliot Williams
# 89184  williel01       June 20, 1989      2010.0  Elliot Williams
# 89193  williel01       June 20, 1989      2010.0  Elliot Williams
# 89205  youngjo01       June 27, 1992      2015.0        Joe Young
# 89208  youngjo01       June 27, 1992      2015.0        Joe Young
#
#             position                 college   salary  season_end  \
# 28     Power Forward       Baylor University  1914544        2017
# 32       Point Guard       Baylor University   750000        2016
# 34     Power Forward       Baylor University   507336        2015
# 39     Small Forward       Baylor University  2038206        2016
# 41     Power Forward       Baylor University   788872        2014
# ...              ...                     ...      ...         ...
# 89175    Point Guard   University of Memphis  1442880        2013
# 89184    Point Guard   University of Memphis  1442880        2013
# 89193    Point Guard   University of Memphis  1442880        2013
# 89205    Point Guard    University of Oregon  1471382        2018
# 89208    Point Guard    University of Oregon  1471382        2018
#
#        season_start                    team        lat        long
# 28             2016           Brooklyn Nets  31.546913  -97.121100
# 32             2015      Philadelphia 76ers  31.546913  -97.121100
# 34             2014           Brooklyn Nets  31.546913  -97.121100
# 39             2015          Boston Celtics  31.546913  -97.121100
# 41             2013          Denver Nuggets  31.546913  -97.121100
# ...             ...                     ...        ...         ...
# 89175          2012  Portland Trail Blazers  35.118750  -89.937493
# 89184          2012  Portland Trail Blazers  35.118750  -89.937493
# 89193          2012  Portland Trail Blazers  35.118750  -89.937493
# 89205          2017          Indiana Pacers  44.044830 -123.072605
# 89208          2017          Indiana Pacers  44.044830 -123.072605
#
# [15853 rows x 12 columns]
# C:\Users\vitor\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
merged = merged.drop_duplicates(['player_id'], keep = "last")

# %%
#set player_id as index
merged = merged.set_index('player_id')

# %%
# Export to csv

merged.to_csv('NBAdataset.csv')

# %%
# Export to json
merged.reset_index().to_json('NBAdataJSON.json', orient = 'records')

# %%
# SQL upload

database_username = input('ENTER USERNAME')
database_password = input('ENTER PASSWORD')
database_name     = 'NBAdataset'
database_connection = sqlalchemy.create_engine('postgresql://{0}:{1}@localhost:5432/{2}'.format(database_username, database_password, database_name))
merged.to_sql(con=database_connection, name='NBAdataset', if_exists='append')
# Out:
# ENTER USERNAMEpostgres
# ENTER PASSWORDpostgres

# %% [markdown]
# **----------END OF CODE----------**
