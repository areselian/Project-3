# %%
import requests
import json 
import pandas as pd

from config import gkey

# %%
NBADS = pd.read_csv("NBAdataset.csv")
NBADF = pd.DataFrame(NBADS)
NBADF["college"]
# Out:
# 0                                 Baylor University
# 1                                 Baylor University
# 2                                 Baylor University
# 3                                 Baylor University
# 4                                 Baylor University
# 5                                 Baylor University
# 6                                 Baylor University
# 7             University of California, Los Angeles
# 8             University of California, Los Angeles
# 9             University of California, Los Angeles
# 10                         University of Pittsburgh
# 11                         University of Pittsburgh
# 12                         University of Pittsburgh
# 13                         University of Pittsburgh
# 14                         University of Pittsburgh
# 15                           University of Kentucky
# 16                         Florida State University
# 17                         Florida State University
# 18                             University of Kansas
# 19                             University of Kansas
# 20                             University of Kansas
# 21                             University of Kansas
# 22                             University of Kansas
# 23                             University of Kansas
# 24                             University of Kansas
# 25                    University of Texas at Austin
# 26                                Temple University
# 27                                Temple University
# 28                                Temple University
# 29                                Temple University
#                            ...
# 1205                                Duke University
# 1206                                Duke University
# 1207                           University of Kansas
# 1208                           University of Kansas
# 1209                           University of Kansas
# 1210                           University of Kansas
# 1211                             University of Utah
# 1212                             University of Utah
# 1213                             University of Utah
# 1214                       University of Washington
# 1215                       University of Washington
# 1216                       University of Washington
# 1217                       University of Washington
# 1218                       University of Washington
# 1219                       University of Washington
# 1220    University of Houston, University of Oregon
# 1221    University of Houston, University of Oregon
# 1222    University of Houston, University of Oregon
# 1223                             Indiana University
# 1224                             Indiana University
# 1225                             Indiana University
# 1226                             Indiana University
# 1227                             Indiana University
# 1228                   University of North Carolina
# 1229                   University of North Carolina
# 1230                   University of North Carolina
# 1231                   University of North Carolina
# 1232                   University of North Carolina
# 1233                   University of North Carolina
# 1234                University of Nevada, Las Vegas
# Name: college, Length: 1235, dtype: object

# %%
#list of colleges
colleges = NBADF["college"]

# Build the endpoint URL
NewDF = pd.DataFrame()
for college in colleges:
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(college, gkey)
    geo_data = requests.get(target_url).json()
    lat = geo_data["results"][0]["geometry"]["location"]["lat"]
    lng = geo_data["results"][0]["geometry"]["location"]["lng"]
    coll_coord = {"name": college, "lat": lat, "long": lng}
    NewDF = NewDF.append(coll_coord, ignore_index=True)

    print(coll_coord)
# Out:
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'University of Pittsburgh', 'lat': 40.4443533, 'long': -79.960835}
# {'name': 'University of Pittsburgh', 'lat': 40.4443533, 'long': -79.960835}
# {'name': 'University of Pittsburgh', 'lat': 40.4443533, 'long': -79.960835}
# {'name': 'University of Pittsburgh', 'lat': 40.4443533, 'long': -79.960835}
# {'name': 'University of Pittsburgh', 'lat': 40.4443533, 'long': -79.960835}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'Florida State University', 'lat': 30.4418778, 'long': -84.2984889}
# {'name': 'Florida State University', 'lat': 30.4418778, 'long': -84.2984889}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'Temple University', 'lat': 39.9805942, 'long': -75.1557376}
# {'name': 'Temple University', 'lat': 39.9805942, 'long': -75.1557376}
# {'name': 'Temple University', 'lat': 39.9805942, 'long': -75.1557376}
# {'name': 'Temple University', 'lat': 39.9805942, 'long': -75.1557376}
# {'name': 'Temple University', 'lat': 39.9805942, 'long': -75.1557376}
# {'name': 'Temple University', 'lat': 39.9805942, 'long': -75.1557376}
# {'name': 'Wake Forest University', 'lat': 36.1355052, 'long': -80.2791958}
# {'name': 'Wake Forest University', 'lat': 36.1355052, 'long': -80.2791958}
# {'name': 'Wake Forest University', 'lat': 36.1355052, 'long': -80.2791958}
# {'name': 'Wake Forest University', 'lat': 36.1355052, 'long': -80.2791958}
# {'name': 'Wake Forest University', 'lat': 36.1355052, 'long': -80.2791958}
# {'name': 'Wake Forest University', 'lat': 36.1355052, 'long': -80.2791958}
# {'name': 'Wake Forest University', 'lat': 36.1355052, 'long': -80.2791958}
# {'name': 'Wake Forest University', 'lat': 36.1355052, 'long': -80.2791958}
# {'name': 'Oklahoma State University', 'lat': 36.1270236, 'long': -97.07372219999999}
# {'name': 'Oklahoma State University', 'lat': 36.1270236, 'long': -97.07372219999999}
# {'name': 'Oklahoma State University', 'lat': 36.1270236, 'long': -97.07372219999999}
# {'name': 'Oklahoma State University', 'lat': 36.1270236, 'long': -97.07372219999999}
# {'name': 'Oklahoma State University', 'lat': 36.1270236, 'long': -97.07372219999999}
# {'name': 'Oklahoma State University', 'lat': 36.1270236, 'long': -97.07372219999999}
# {'name': 'University of Virginia', 'lat': 38.0335529, 'long': -78.5079772}
# {'name': 'University of Virginia', 'lat': 38.0335529, 'long': -78.5079772}
# {'name': 'University of Virginia', 'lat': 38.0335529, 'long': -78.5079772}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'University of Nevada, Reno', 'lat': 39.5441917, 'long': -119.816397}
# {'name': 'University of Nevada, Reno', 'lat': 39.5441917, 'long': -119.816397}
# {'name': 'University of Nevada, Reno', 'lat': 39.5441917, 'long': -119.816397}
# {'name': 'University of Nevada, Reno', 'lat': 39.5441917, 'long': -119.816397}
# {'name': 'University of Nevada, Reno', 'lat': 39.5441917, 'long': -119.816397}
# {'name': 'University of Nevada, Reno', 'lat': 39.5441917, 'long': -119.816397}
# {'name': 'University of Nevada, Reno', 'lat': 39.5441917, 'long': -119.816397}
# {'name': 'Florida State University', 'lat': 30.4418778, 'long': -84.2984889}
# {'name': 'University of New Mexico', 'lat': 35.0843187, 'long': -106.6197812}
# {'name': 'University of New Mexico', 'lat': 35.0843187, 'long': -106.6197812}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'University of Florida', 'lat': 29.6436325, 'long': -82.3549302}
# {'name': 'University of Florida', 'lat': 29.6436325, 'long': -82.3549302}
# {'name': 'University of Florida', 'lat': 29.6436325, 'long': -82.3549302}
# {'name': 'University of Florida', 'lat': 29.6436325, 'long': -82.3549302}
# {'name': 'University of Florida', 'lat': 29.6436325, 'long': -82.3549302}
# {'name': 'University of Florida', 'lat': 29.6436325, 'long': -82.3549302}
# {'name': 'Florida State University', 'lat': 30.4418778, 'long': -84.2984889}
# {'name': 'Florida State University', 'lat': 30.4418778, 'long': -84.2984889}
# {'name': 'University of Oregon', 'lat': 44.0448302, 'long': -123.0726055}
# {'name': "Saint Joseph's University", 'lat': 39.9951217, 'long': -75.23993279999999}
# {'name': "Saint Joseph's University", 'lat': 39.9951217, 'long': -75.23993279999999}
# {'name': 'University of Nevada, Las Vegas', 'lat': 36.1085197, 'long': -115.1431709}
# {'name': 'University of Nevada, Las Vegas', 'lat': 36.1085197, 'long': -115.1431709}
# {'name': 'University of Nevada, Las Vegas', 'lat': 36.1085197, 'long': -115.1431709}
# {'name': 'University of Nevada, Las Vegas', 'lat': 36.1085197, 'long': -115.1431709}
# {'name': 'University of Nevada, Las Vegas', 'lat': 36.1085197, 'long': -115.1431709}
# {'name': 'Oakland University', 'lat': 42.6679486, 'long': -83.2081632}
# {'name': 'Providence College', 'lat': 41.8440925, 'long': -71.4381653}
# {'name': 'Providence College', 'lat': 41.8440925, 'long': -71.4381653}
# {'name': 'Providence College', 'lat': 41.8440925, 'long': -71.4381653}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'Clemson University', 'lat': 34.6738437, 'long': -82.8368654}
# {'name': 'Clemson University', 'lat': 34.6738437, 'long': -82.8368654}
# {'name': 'Clemson University', 'lat': 34.6738437, 'long': -82.8368654}
# {'name': 'Clemson University', 'lat': 34.6738437, 'long': -82.8368654}
# {'name': 'Clemson University', 'lat': 34.6738437, 'long': -82.8368654}
# {'name': 'Clemson University', 'lat': 34.6738437, 'long': -82.8368654}
# {'name': 'Clemson University', 'lat': 34.6738437, 'long': -82.8368654}
# {'name': 'Clemson University', 'lat': 34.6738437, 'long': -82.8368654}
# {'name': 'Clemson University', 'lat': 34.6738437, 'long': -82.8368654}
# {'name': 'Iowa State University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Iowa State University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of Virginia', 'lat': 38.0335529, 'long': -78.5079772}
# {'name': 'University of Virginia', 'lat': 38.0335529, 'long': -78.5079772}
# {'name': 'University of Oregon', 'lat': 44.0448302, 'long': -123.0726055}
# {'name': 'Providence College', 'lat': 41.8440925, 'long': -71.4381653}
# {'name': 'Providence College', 'lat': 41.8440925, 'long': -71.4381653}
# {'name': 'Providence College', 'lat': 41.8440925, 'long': -71.4381653}
# {'name': 'Providence College', 'lat': 41.8440925, 'long': -71.4381653}
# {'name': 'University of California', 'lat': 37.8718992, 'long': -122.2585399}
# {'name': 'University of California', 'lat': 37.8718992, 'long': -122.2585399}
# {'name': 'Southern Methodist University', 'lat': 32.8412178, 'long': -96.78451749999999}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'University of Georgia', 'lat': 33.9480053, 'long': -83.3773221}
# {'name': 'University of Georgia', 'lat': 33.9480053, 'long': -83.3773221}
# {'name': 'University of Georgia', 'lat': 33.9480053, 'long': -83.3773221}
# {'name': 'University of Georgia', 'lat': 33.9480053, 'long': -83.3773221}
# {'name': 'University of Georgia', 'lat': 33.9480053, 'long': -83.3773221}
# {'name': 'Murray State University', 'lat': 36.6163842, 'long': -88.3214979}
# {'name': 'Murray State University', 'lat': 36.6163842, 'long': -88.3214979}
# {'name': 'Murray State University', 'lat': 36.6163842, 'long': -88.3214979}
# {'name': 'Murray State University', 'lat': 36.6163842, 'long': -88.3214979}
# {'name': 'Murray State University', 'lat': 36.6163842, 'long': -88.3214979}
# {'name': 'Murray State University', 'lat': 36.6163842, 'long': -88.3214979}
# {'name': 'University of Louisville, University of Texas at El Paso', 'lat': 31.7709368, 'long': -106.5046405}
# {'name': 'University of Louisville, University of Texas at El Paso', 'lat': 31.7709368, 'long': -106.5046405}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Xavier University', 'lat': 39.149448, 'long': -84.47363740000002}
# {'name': 'University of Tulsa, University of Missouri', 'lat': 38.9403808, 'long': -92.32773750000001}
# {'name': 'University of Tulsa, University of Missouri', 'lat': 38.9403808, 'long': -92.32773750000001}
# {'name': 'University of Tulsa, University of Missouri', 'lat': 38.9403808, 'long': -92.32773750000001}
# {'name': 'University of Tulsa, University of Missouri', 'lat': 38.9403808, 'long': -92.32773750000001}
# {'name': 'Cleveland State University', 'lat': 41.5025072, 'long': -81.6746268}
# {'name': 'Cleveland State University', 'lat': 41.5025072, 'long': -81.6746268}
# {'name': 'Cleveland State University', 'lat': 41.5025072, 'long': -81.6746268}
# {'name': 'Cleveland State University', 'lat': 41.5025072, 'long': -81.6746268}
# {'name': 'Cleveland State University', 'lat': 41.5025072, 'long': -81.6746268}
# {'name': 'Cleveland State University', 'lat': 41.5025072, 'long': -81.6746268}
# {'name': 'Wake Forest University', 'lat': 36.1355052, 'long': -80.2791958}
# {'name': 'Gonzaga University', 'lat': 47.66703210000001, 'long': -117.4014343}
# {'name': 'University of Notre Dame', 'lat': 41.7055716, 'long': -86.2353388}
# {'name': 'University of Notre Dame', 'lat': 41.7055716, 'long': -86.2353388}
# {'name': 'University of Notre Dame', 'lat': 41.7055716, 'long': -86.2353388}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of California', 'lat': 37.8718992, 'long': -122.2585399}
# {'name': 'University of California', 'lat': 37.8718992, 'long': -122.2585399}
# {'name': 'University of California', 'lat': 37.8718992, 'long': -122.2585399}
# {'name': 'University of California', 'lat': 37.8718992, 'long': -122.2585399}
# {'name': 'Indiana University, Xavier University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University, Xavier University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University, Xavier University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University, Xavier University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University, Xavier University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University, Xavier University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Oregon State University', 'lat': 44.5637806, 'long': -123.2794443}
# {'name': 'Oregon State University', 'lat': 44.5637806, 'long': -123.2794443}
# {'name': 'Oregon State University', 'lat': 44.5637806, 'long': -123.2794443}
# {'name': 'Oregon State University', 'lat': 44.5637806, 'long': -123.2794443}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'University of Wisconsin', 'lat': 43.076592, 'long': -89.4124875}
# {'name': 'University of Wisconsin', 'lat': 43.076592, 'long': -89.4124875}
# {'name': 'University of Wisconsin', 'lat': 43.076592, 'long': -89.4124875}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Louisville', 'lat': 38.2122761, 'long': -85.75850229999999}
# {'name': 'University of Louisville', 'lat': 38.2122761, 'long': -85.75850229999999}
# {'name': 'University of Louisville', 'lat': 38.2122761, 'long': -85.75850229999999}
# {'name': 'University of Louisville', 'lat': 38.2122761, 'long': -85.75850229999999}
# {'name': 'University of Louisville', 'lat': 38.2122761, 'long': -85.75850229999999}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'University of Oregon', 'lat': 44.0448302, 'long': -123.0726055}
# {'name': 'University of Oregon, University of Houston', 'lat': 29.7199489, 'long': -95.3422334}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'Providence College', 'lat': 41.8440925, 'long': -71.4381653}
# {'name': 'Providence College', 'lat': 41.8440925, 'long': -71.4381653}
# {'name': 'Wichita State University', 'lat': 37.7186367, 'long': -97.29414140000002}
# {'name': 'Wichita State University', 'lat': 37.7186367, 'long': -97.29414140000002}
# {'name': 'West Virginia University', 'lat': 39.6480359, 'long': -79.9697147}
# {'name': 'West Virginia University', 'lat': 39.6480359, 'long': -79.9697147}
# {'name': 'West Virginia University', 'lat': 39.6480359, 'long': -79.9697147}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Missouri', 'lat': 38.9403808, 'long': -92.32773750000001}
# {'name': 'California State University, Long Beach', 'lat': 33.7838235, 'long': -118.1140904}
# {'name': 'California State University, Long Beach', 'lat': 33.7838235, 'long': -118.1140904}
# {'name': 'California State University, Long Beach', 'lat': 33.7838235, 'long': -118.1140904}
# {'name': 'California State University, Long Beach', 'lat': 33.7838235, 'long': -118.1140904}
# {'name': 'California State University, Long Beach', 'lat': 33.7838235, 'long': -118.1140904}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Oklahoma State University', 'lat': 36.1270236, 'long': -97.07372219999999}
# {'name': 'Western Kentucky University', 'lat': 36.983537, 'long': -86.4573752}
# {'name': 'Western Kentucky University', 'lat': 36.983537, 'long': -86.4573752}
# {'name': 'Western Kentucky University', 'lat': 36.983537, 'long': -86.4573752}
# {'name': 'Western Kentucky University', 'lat': 36.983537, 'long': -86.4573752}
# {'name': 'Western Kentucky University', 'lat': 36.983537, 'long': -86.4573752}
# {'name': 'Western Kentucky University', 'lat': 36.983537, 'long': -86.4573752}
# {'name': 'Western Kentucky University', 'lat': 36.983537, 'long': -86.4573752}
# {'name': 'Western Kentucky University', 'lat': 36.983537, 'long': -86.4573752}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Morehead State University', 'lat': 38.1886162, 'long': -83.4315122}
# {'name': 'Morehead State University', 'lat': 38.1886162, 'long': -83.4315122}
# {'name': 'Morehead State University', 'lat': 38.1886162, 'long': -83.4315122}
# {'name': 'Morehead State University', 'lat': 38.1886162, 'long': -83.4315122}
# {'name': 'Morehead State University', 'lat': 38.1886162, 'long': -83.4315122}
# {'name': 'Morehead State University', 'lat': 38.1886162, 'long': -83.4315122}
# {'name': 'Morehead State University', 'lat': 38.1886162, 'long': -83.4315122}
# {'name': 'Georgia Institute of Technology', 'lat': 33.7756178, 'long': -84.39628499999999}
# {'name': 'Georgia Institute of Technology', 'lat': 33.7756178, 'long': -84.39628499999999}
# {'name': 'Georgia Institute of Technology', 'lat': 33.7756178, 'long': -84.39628499999999}
# {'name': 'Georgia Institute of Technology', 'lat': 33.7756178, 'long': -84.39628499999999}
# {'name': 'Georgia Institute of Technology', 'lat': 33.7756178, 'long': -84.39628499999999}
# {'name': 'Georgia Institute of Technology', 'lat': 33.7756178, 'long': -84.39628499999999}
# {'name': 'Georgia Institute of Technology', 'lat': 33.7756178, 'long': -84.39628499999999}
# {'name': 'Georgia Institute of Technology', 'lat': 33.7756178, 'long': -84.39628499999999}
# {'name': 'Arizona State University', 'lat': 33.4242399, 'long': -111.9280527}
# {'name': 'Arizona State University', 'lat': 33.4242399, 'long': -111.9280527}
# {'name': 'Stanford University', 'lat': 37.4274745, 'long': -122.169719}
# {'name': 'Stanford University', 'lat': 37.4274745, 'long': -122.169719}
# {'name': 'Stanford University', 'lat': 37.4274745, 'long': -122.169719}
# {'name': 'Stanford University', 'lat': 37.4274745, 'long': -122.169719}
# {'name': 'Stanford University', 'lat': 37.4274745, 'long': -122.169719}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'San Diego State University', 'lat': 32.7759894, 'long': -117.0712533}
# {'name': 'San Diego State University', 'lat': 32.7759894, 'long': -117.0712533}
# {'name': 'San Diego State University', 'lat': 32.7759894, 'long': -117.0712533}
# {'name': 'San Diego State University', 'lat': 32.7759894, 'long': -117.0712533}
# {'name': 'San Diego State University', 'lat': 32.7759894, 'long': -117.0712533}
# {'name': 'Brigham Young University', 'lat': 40.2518435, 'long': -111.6493156}
# {'name': 'Brigham Young University', 'lat': 40.2518435, 'long': -111.6493156}
# {'name': 'Brigham Young University', 'lat': 40.2518435, 'long': -111.6493156}
# {'name': 'Brigham Young University', 'lat': 40.2518435, 'long': -111.6493156}
# {'name': 'Brigham Young University', 'lat': 40.2518435, 'long': -111.6493156}
# {'name': 'Brigham Young University', 'lat': 40.2518435, 'long': -111.6493156}
# {'name': 'Brigham Young University', 'lat': 40.2518435, 'long': -111.6493156}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'Duke University, Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Duke University, Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'California State University, Fresno', 'lat': 36.8133631, 'long': -119.7460947}
# {'name': 'California State University, Fresno', 'lat': 36.8133631, 'long': -119.7460947}
# {'name': 'California State University, Fresno', 'lat': 36.8133631, 'long': -119.7460947}
# {'name': 'California State University, Fresno', 'lat': 36.8133631, 'long': -119.7460947}
# {'name': 'California State University, Fresno', 'lat': 36.8133631, 'long': -119.7460947}
# {'name': 'California State University, Fresno', 'lat': 36.8133631, 'long': -119.7460947}
# {'name': 'California State University, Fresno', 'lat': 36.8133631, 'long': -119.7460947}
# {'name': 'California State University, Fresno', 'lat': 36.8133631, 'long': -119.7460947}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'College of Charleston', 'lat': 32.7834441, 'long': -79.93700179999999}
# {'name': 'College of Charleston', 'lat': 32.7834441, 'long': -79.93700179999999}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'University of Notre Dame', 'lat': 41.7055716, 'long': -86.2353388}
# {'name': 'University of Notre Dame', 'lat': 41.7055716, 'long': -86.2353388}
# {'name': 'University of Notre Dame', 'lat': 41.7055716, 'long': -86.2353388}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Virginia Polytechnic Institute and State University', 'lat': 37.22838429999999, 'long': -80.42341669999999}
# {'name': 'Virginia Polytechnic Institute and State University', 'lat': 37.22838429999999, 'long': -80.42341669999999}
# {'name': 'Virginia Polytechnic Institute and State University', 'lat': 37.22838429999999, 'long': -80.42341669999999}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'Iowa State University, Louisiana State University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Iowa State University, Louisiana State University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Iowa State University, Louisiana State University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Purdue University', 'lat': 40.4237054, 'long': -86.92119459999999}
# {'name': 'Purdue University', 'lat': 40.4237054, 'long': -86.92119459999999}
# {'name': 'University of Notre Dame', 'lat': 41.7055716, 'long': -86.2353388}
# {'name': 'University of Notre Dame', 'lat': 41.7055716, 'long': -86.2353388}
# {'name': 'University of Notre Dame', 'lat': 41.7055716, 'long': -86.2353388}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': "St. John's University", 'lat': 40.7220627, 'long': -73.79421119999999}
# {'name': "St. John's University", 'lat': 40.7220627, 'long': -73.79421119999999}
# {'name': "St. John's University", 'lat': 40.7220627, 'long': -73.79421119999999}
# {'name': "St. John's University", 'lat': 40.7220627, 'long': -73.79421119999999}
# {'name': "St. John's University", 'lat': 40.7220627, 'long': -73.79421119999999}
# {'name': "St. John's University", 'lat': 40.7220627, 'long': -73.79421119999999}
# {'name': 'University of Richmond', 'lat': 37.5751669, 'long': -77.5407146}
# {'name': 'University of Richmond', 'lat': 37.5751669, 'long': -77.5407146}
# {'name': 'University of Richmond', 'lat': 37.5751669, 'long': -77.5407146}
# {'name': 'University of Richmond', 'lat': 37.5751669, 'long': -77.5407146}
# {'name': 'University of Louisville', 'lat': 38.2122761, 'long': -85.75850229999999}
# {'name': 'University of Louisville', 'lat': 38.2122761, 'long': -85.75850229999999}
# {'name': 'University of Louisville', 'lat': 38.2122761, 'long': -85.75850229999999}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'University of Virginia', 'lat': 38.0335529, 'long': -78.5079772}
# {'name': 'University of Virginia', 'lat': 38.0335529, 'long': -78.5079772}
# {'name': 'University of Virginia', 'lat': 38.0335529, 'long': -78.5079772}
# {'name': 'University of Virginia', 'lat': 38.0335529, 'long': -78.5079772}
# {'name': 'University of Tennessee', 'lat': 35.9544013, 'long': -83.92945639999999}
# {'name': 'University of Tennessee', 'lat': 35.9544013, 'long': -83.92945639999999}
# {'name': 'University of Tennessee', 'lat': 35.9544013, 'long': -83.92945639999999}
# {'name': 'University of Tennessee', 'lat': 35.9544013, 'long': -83.92945639999999}
# {'name': 'University of Tennessee', 'lat': 35.9544013, 'long': -83.92945639999999}
# {'name': 'University of Tennessee', 'lat': 35.9544013, 'long': -83.92945639999999}
# {'name': 'University of Tennessee', 'lat': 35.9544013, 'long': -83.92945639999999}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'Villanova University', 'lat': 40.0378952, 'long': -75.34333149999999}
# {'name': 'Butler University', 'lat': 39.8405491, 'long': -86.1708927}
# {'name': 'Butler University', 'lat': 39.8405491, 'long': -86.1708927}
# {'name': 'Butler University', 'lat': 39.8405491, 'long': -86.1708927}
# {'name': 'Butler University', 'lat': 39.8405491, 'long': -86.1708927}
# {'name': 'Butler University', 'lat': 39.8405491, 'long': -86.1708927}
# {'name': 'Butler University', 'lat': 39.8405491, 'long': -86.1708927}
# {'name': 'Butler University', 'lat': 39.8405491, 'long': -86.1708927}
# {'name': 'Butler University', 'lat': 39.8405491, 'long': -86.1708927}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of Oklahoma', 'lat': 35.2058936, 'long': -97.4457137}
# {'name': 'University of Oklahoma', 'lat': 35.2058936, 'long': -97.4457137}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of New Mexico', 'lat': 35.0843187, 'long': -106.6197812}
# {'name': 'University of New Mexico', 'lat': 35.0843187, 'long': -106.6197812}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'Bowling Green State University', 'lat': 41.3797788, 'long': -83.6300826}
# {'name': 'Bowling Green State University', 'lat': 41.3797788, 'long': -83.6300826}
# {'name': 'Bowling Green State University', 'lat': 41.3797788, 'long': -83.6300826}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'University of California, Los Angeles', 'lat': 34.068921, 'long': -118.4451811}
# {'name': 'Mississippi State University, Duke University', 'lat': 33.4551742, 'long': -88.79437659999999}
# {'name': 'Mississippi State University, Duke University', 'lat': 33.4551742, 'long': -88.79437659999999}
# {'name': 'Mississippi State University, Duke University', 'lat': 33.4551742, 'long': -88.79437659999999}
# {'name': 'Mississippi State University, Duke University', 'lat': 33.4551742, 'long': -88.79437659999999}
# {'name': 'Stanford University', 'lat': 37.4274745, 'long': -122.169719}
# {'name': 'Stanford University', 'lat': 37.4274745, 'long': -122.169719}
# {'name': 'Stanford University', 'lat': 37.4274745, 'long': -122.169719}
# {'name': 'Purdue University', 'lat': 40.4237054, 'long': -86.92119459999999}
# {'name': 'Purdue University', 'lat': 40.4237054, 'long': -86.92119459999999}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Florida State University', 'lat': 30.4418778, 'long': -84.2984889}
# {'name': 'Kansas State University', 'lat': 39.1974437, 'long': -96.5847249}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Boston College', 'lat': 42.3355488, 'long': -71.16849450000001}
# {'name': 'Boston College', 'lat': 42.3355488, 'long': -71.16849450000001}
# {'name': 'Boston College', 'lat': 42.3355488, 'long': -71.16849450000001}
# {'name': 'Boston College', 'lat': 42.3355488, 'long': -71.16849450000001}
# {'name': 'Boston College', 'lat': 42.3355488, 'long': -71.16849450000001}
# {'name': 'Boston College', 'lat': 42.3355488, 'long': -71.16849450000001}
# {'name': 'Boston College', 'lat': 42.3355488, 'long': -71.16849450000001}
# {'name': 'Florida State University', 'lat': 30.4418778, 'long': -84.2984889}
# {'name': 'Florida State University', 'lat': 30.4418778, 'long': -84.2984889}
# {'name': 'Florida State University', 'lat': 30.4418778, 'long': -84.2984889}
# {'name': 'Florida State University', 'lat': 30.4418778, 'long': -84.2984889}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Hofstra University', 'lat': 40.7166872, 'long': -73.5993965}
# {'name': 'Hofstra University', 'lat': 40.7166872, 'long': -73.5993965}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Nevada, Reno', 'lat': 39.5441917, 'long': -119.816397}
# {'name': 'University of Nevada, Reno', 'lat': 39.5441917, 'long': -119.816397}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'Purdue University', 'lat': 40.4237054, 'long': -86.92119459999999}
# {'name': 'Purdue University', 'lat': 40.4237054, 'long': -86.92119459999999}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'Loyola Marymount University, University of California, Santa Barbara', 'lat': 33.9701634, 'long': -118.4166111}
# {'name': 'Loyola Marymount University, University of California, Santa Barbara', 'lat': 33.9701634, 'long': -118.4166111}
# {'name': 'Loyola Marymount University, University of California, Santa Barbara', 'lat': 33.9701634, 'long': -118.4166111}
# {'name': 'Loyola Marymount University, University of California, Santa Barbara', 'lat': 33.9701634, 'long': -118.4166111}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'Iowa State University, Syracuse University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Iowa State University, Syracuse University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Iowa State University, Syracuse University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Iowa State University, Syracuse University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Iowa State University, Syracuse University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Iowa State University, Syracuse University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Iowa State University, Syracuse University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Iowa State University, Syracuse University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Marquette University', 'lat': 43.0388337, 'long': -87.92856669999999}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'University of South Florida', 'lat': 28.0587031, 'long': -82.41385389999999}
# {'name': 'University of South Florida', 'lat': 28.0587031, 'long': -82.41385389999999}
# {'name': 'University of South Florida', 'lat': 28.0587031, 'long': -82.41385389999999}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'University of Tulsa', 'lat': 36.1520526, 'long': -95.94607529999999}
# {'name': 'University of Tulsa', 'lat': 36.1520526, 'long': -95.94607529999999}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'University of Wisconsin', 'lat': 43.076592, 'long': -89.4124875}
# {'name': 'University of Wisconsin', 'lat': 43.076592, 'long': -89.4124875}
# {'name': 'University of Wisconsin', 'lat': 43.076592, 'long': -89.4124875}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Utah', 'lat': 40.7649368, 'long': -111.8421021}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# ...
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'University of Cincinnati', 'lat': 39.1329219, 'long': -84.51495039999999}
# {'name': 'University of Cincinnati', 'lat': 39.1329219, 'long': -84.51495039999999}
# {'name': 'University of Cincinnati', 'lat': 39.1329219, 'long': -84.51495039999999}
# {'name': 'University of Cincinnati', 'lat': 39.1329219, 'long': -84.51495039999999}
# {'name': 'University of Cincinnati', 'lat': 39.1329219, 'long': -84.51495039999999}
# {'name': 'University of Cincinnati', 'lat': 39.1329219, 'long': -84.51495039999999}
# {'name': 'University of Cincinnati', 'lat': 39.1329219, 'long': -84.51495039999999}
# {'name': 'University of Cincinnati', 'lat': 39.1329219, 'long': -84.51495039999999}
# {'name': 'University of Cincinnati', 'lat': 39.1329219, 'long': -84.51495039999999}
# {'name': 'University of Cincinnati', 'lat': 39.1329219, 'long': -84.51495039999999}
# {'name': 'University of Tennessee', 'lat': 35.9544013, 'long': -83.92945639999999}
# {'name': 'University of Tennessee', 'lat': 35.9544013, 'long': -83.92945639999999}
# {'name': 'University of Tennessee', 'lat': 35.9544013, 'long': -83.92945639999999}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Purdue University', 'lat': 40.4237054, 'long': -86.92119459999999}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'Vanderbilt University', 'lat': 36.1447034, 'long': -86.8026551}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Georgia', 'lat': 33.9480053, 'long': -83.3773221}
# {'name': 'University of Georgia', 'lat': 33.9480053, 'long': -83.3773221}
# {'name': 'Washington State University', 'lat': 46.7319225, 'long': -117.1542121}
# {'name': 'Washington State University', 'lat': 46.7319225, 'long': -117.1542121}
# {'name': 'Washington State University', 'lat': 46.7319225, 'long': -117.1542121}
# {'name': 'Washington State University', 'lat': 46.7319225, 'long': -117.1542121}
# {'name': 'Washington State University', 'lat': 46.7319225, 'long': -117.1542121}
# {'name': 'Washington State University', 'lat': 46.7319225, 'long': -117.1542121}
# {'name': 'Washington State University', 'lat': 46.7319225, 'long': -117.1542121}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of South Carolina', 'lat': 33.9937575, 'long': -81.0299186}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'Ohio State University', 'lat': 40.0068363, 'long': -83.0306222}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Texas at Austin', 'lat': 30.2849185, 'long': -97.7340567}
# {'name': 'University of Michigan, Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'University of Michigan, Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'University of Michigan, Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'University of Michigan, Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'University of Michigan, Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'University of Michigan, Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Michigan State University', 'lat': 42.701848, 'long': -84.4821719}
# {'name': 'Mississippi State University', 'lat': 33.4551742, 'long': -88.79437659999999}
# {'name': 'Mississippi State University', 'lat': 33.4551742, 'long': -88.79437659999999}
# {'name': 'Mississippi State University', 'lat': 33.4551742, 'long': -88.79437659999999}
# {'name': 'Mississippi State University', 'lat': 33.4551742, 'long': -88.79437659999999}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Nevada, Las Vegas', 'lat': 36.1085197, 'long': -115.1431709}
# {'name': 'University of Nevada, Las Vegas', 'lat': 36.1085197, 'long': -115.1431709}
# {'name': 'University of Nevada, Las Vegas', 'lat': 36.1085197, 'long': -115.1431709}
# {'name': 'University of Nevada, Las Vegas', 'lat': 36.1085197, 'long': -115.1431709}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'University of Southern California', 'lat': 34.0223519, 'long': -118.285117}
# {'name': 'University of Southern California', 'lat': 34.0223519, 'long': -118.285117}
# {'name': 'University of Southern California', 'lat': 34.0223519, 'long': -118.285117}
# {'name': 'University of Southern California', 'lat': 34.0223519, 'long': -118.285117}
# {'name': 'University of Southern California', 'lat': 34.0223519, 'long': -118.285117}
# {'name': 'University of Southern California', 'lat': 34.0223519, 'long': -118.285117}
# {'name': 'University of Southern California', 'lat': 34.0223519, 'long': -118.285117}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'Syracuse University', 'lat': 43.0391534, 'long': -76.1351158}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Connecticut', 'lat': 41.8077414, 'long': -72.2539805}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'University of Kentucky', 'lat': 38.0306511, 'long': -84.5039697}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'Baylor University', 'lat': 31.5469132, 'long': -97.1210998}
# {'name': 'North Carolina State University', 'lat': 35.7846633, 'long': -78.6820946}
# {'name': 'North Carolina State University', 'lat': 35.7846633, 'long': -78.6820946}
# {'name': 'North Carolina State University', 'lat': 35.7846633, 'long': -78.6820946}
# {'name': 'North Carolina State University', 'lat': 35.7846633, 'long': -78.6820946}
# {'name': 'University of Oklahoma', 'lat': 35.2058936, 'long': -97.4457137}
# {'name': 'University of Colorado', 'lat': 40.00758099999999, 'long': -105.2659417}
# {'name': 'Iowa State University', 'lat': 42.0266187, 'long': -93.6464654}
# {'name': 'Seton Hall University', 'lat': 40.7433773, 'long': -74.2465446}
# {'name': 'Seton Hall University', 'lat': 40.7433773, 'long': -74.2465446}
# {'name': 'Marshall University', 'lat': 38.4235252, 'long': -82.42641449999999}
# {'name': 'Marshall University', 'lat': 38.4235252, 'long': -82.42641449999999}
# {'name': 'Marshall University', 'lat': 38.4235252, 'long': -82.42641449999999}
# {'name': 'Marshall University', 'lat': 38.4235252, 'long': -82.42641449999999}
# {'name': 'Marshall University', 'lat': 38.4235252, 'long': -82.42641449999999}
# {'name': 'Marshall University', 'lat': 38.4235252, 'long': -82.42641449999999}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'University of Arizona', 'lat': 32.2318851, 'long': -110.9501094}
# {'name': 'Duke University, University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'Duke University, University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'Duke University, University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'Duke University, University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'Duke University, University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'Duke University, University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'Duke University, University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'Duke University, University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'Duke University, University of Memphis', 'lat': 35.1187498, 'long': -89.9374928}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Maryland', 'lat': 38.9869183, 'long': -76.9425543}
# {'name': 'University of Michigan', 'lat': 42.2780436, 'long': -83.7382241}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'Duke University', 'lat': 36.0014258, 'long': -78.9382286}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Kansas', 'lat': 38.9543439, 'long': -95.2557961}
# {'name': 'University of Utah', 'lat': 40.7649368, 'long': -111.8421021}
# {'name': 'University of Utah', 'lat': 40.7649368, 'long': -111.8421021}
# {'name': 'University of Utah', 'lat': 40.7649368, 'long': -111.8421021}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Washington', 'lat': 47.6912794, 'long': -122.3176141}
# {'name': 'University of Houston, University of Oregon', 'lat': 44.0448302, 'long': -123.0726055}
# {'name': 'University of Houston, University of Oregon', 'lat': 44.0448302, 'long': -123.0726055}
# {'name': 'University of Houston, University of Oregon', 'lat': 44.0448302, 'long': -123.0726055}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'Indiana University', 'lat': 39.1754487, 'long': -86.512627}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of North Carolina', 'lat': 35.9049122, 'long': -79.0469134}
# {'name': 'University of Nevada, Las Vegas', 'lat': 36.1085197, 'long': -115.1431709}

# %%
NewDF.head()
# Out:
#          lat     long               name
# 0  31.546913 -97.1211  Baylor University
# 1  31.546913 -97.1211  Baylor University
# 2  31.546913 -97.1211  Baylor University
# 3  31.546913 -97.1211  Baylor University
# 4  31.546913 -97.1211  Baylor University

# %%
NewDF.to_csv('Coords.csv', index=False)
