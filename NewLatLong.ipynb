# %%
import pandas as pd
import sqlalchemy

# %%
latlong = pd.read_csv('LatLongNBA.csv')

# %%
latlong = latlong.drop_duplicates(['player_id'], keep = "last")

# %%
latlong = latlong.set_index('player_id')

# %%
latlong.head(100)
# Out:
#            birthDate  draft_year              name  \
# player_id
# acyqu01     6-Oct-90      2012.0        Quincy Acy
# jackspi01  29-Aug-91      2013.0    Pierre Jackson
# jeffeco01  26-Dec-90      2014.0    Cory Jefferson
# jonespe01  24-Sep-91      2012.0       Perry Jones
# millequ01  18-Nov-92      2012.0     Quincy Miller
# ...              ...         ...               ...
# bartowi01   6-Jan-91      2012.0       Will Barton
# bealbr01   28-Jun-93      2012.0      Bradley Beal
# murpher01  26-Oct-90      2013.0       Erik Murphy
# parsoch01  25-Oct-88      2011.0  Chandler Parsons
# belljo01    7-Jan-95      2017.0       Jordan Bell
#
#                                   position                college      salary  \
# player_id
# acyqu01    Power Forward and Small Forward      Baylor University   1709538.0
# jackspi01                      Point Guard      Baylor University    105498.0
# jeffeco01                    Power Forward      Baylor University    421449.0
# jonespe01  Small Forward and Power Forward      Baylor University   2038206.0
# millequ01                    Power Forward      Baylor University     50000.0
# ...                                    ...                    ...         ...
# bartowi01                   Shooting Guard  University of Memphis   3533333.0
# bealbr01                    Shooting Guard  University of Florida  23775506.0
# murpher01                           Center  University of Florida    100000.0
# parsoch01                    Small Forward  University of Florida  23112004.0
# belljo01                            Center   University of Oregon    815615.0
#
#            season_end  season_start                   team        lat  \
# player_id
# acyqu01        2018.0        2017.0          Brooklyn Nets  31.546913
# jackspi01      2017.0        2016.0       Dallas Mavericks  31.546913
# jeffeco01      2016.0        2015.0           Phoenix Suns  31.546913
# jonespe01      2016.0        2015.0         Boston Celtics  31.546913
# millequ01      2016.0        2015.0          Brooklyn Nets  31.546913
# ...               ...           ...                    ...        ...
# bartowi01      2018.0        2017.0         Denver Nuggets  35.118750
# bealbr01       2018.0        2017.0     Washington Wizards  29.643632
# murpher01      2015.0        2014.0         Boston Celtics  29.643632
# parsoch01      2018.0        2017.0      Memphis Grizzlies  29.643632
# belljo01       2018.0        2017.0  Golden State Warriors  44.044830
#
#                  long
# player_id
# acyqu01    -97.121100
# jackspi01  -97.121100
# jeffeco01  -97.121100
# jonespe01  -97.121100
# millequ01  -97.121100
# ...               ...
# bartowi01  -89.937493
# bealbr01   -82.354930
# murpher01  -82.354930
# parsoch01  -82.354930
# belljo01  -123.072605
#
# [100 rows x 11 columns]

# %%
latlong.reset_index().to_json('NBAdataJSON.json', orient = 'records')

# %%
# SQL upload

database_username = input('ENTER USERNAME')
database_password = input('ENTER PASSWORD')
database_name     = 'NBAdataset'
database_connection = sqlalchemy.create_engine('postgresql://{0}:{1}@localhost:5432/{2}'.format(database_username, database_password, database_name))
latlong.to_sql(con=database_connection, name='NBAdataset', if_exists='append')
# Out:
# ENTER USERNAMEpostgres
# ENTER PASSWORDpostgres
